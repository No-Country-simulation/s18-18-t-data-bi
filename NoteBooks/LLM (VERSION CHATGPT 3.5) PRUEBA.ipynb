# %%
import pandas as pd

# Cargar el dataset
data = pd.read_csv('\\Users\\TB\\Downloads\\NASA\\NasaFire.csv')

data.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  -13.2674   -45.5538       320.0   1.1    1.0  2023-01-01       128
# 1  -13.2689   -45.5637       323.4   1.1    1.0  2023-01-01       128
# 2  -13.2704   -45.5736       311.9   1.1    1.0  2023-01-01       128
# 3  -13.3373   -44.1169       303.3   1.3    1.1  2023-01-01       128
# 4   41.1623   123.0031       303.4   1.3    1.1  2023-01-01       210
#
#   satellite instrument  confidence  version  bright_t31   frp daynight  type
# 0     Terra      MODIS         100    61.03       291.2  20.0        N     0
# 1     Terra      MODIS         100    61.03       291.7  23.8        N     0
# 2     Terra      MODIS          84    61.03       291.1  12.2        N     0
# 3     Terra      MODIS          54    61.03       292.5   7.0        N     0
# 4     Terra      MODIS          56    61.03       270.7  14.8        D     2

# %%
def generate_context(data):
    # Convertir el df a texto
    return data.to_string()

# %%
# Simulacion
#
import openai

openai.api_key = 'sk-mSlP8yHKrpMvMguIDRiToISWzojc2AdN0HXqfRLVkjT3BlbkFJounvyA5devb2iBewSOTh7bArSH9TovatQJ5Q1nE1wA' # Secreta teoricamente xd

def ask_gpt(question, context):
    # Combina la pregunta con el contexto del dataset
    prompt = f"{context}\n\nPregunta: {question}\nRespuesta:"
    
    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",  
            messages=[{"role": "user", "content": prompt}],
            max_tokens=150,  # Limitar la cantidad de tokens en la respuesta
            n=1,  # Cantidad de repuestas que quiero
            stop=None,  # parar o no la cantidad de respuesta
            temperature=0.7  # Controlar la creatividad de la respuesta
        )
        
        # Devolver la respuesta de GPT
        return response['choices'][0]['message']['content']
    
    except Exception as e:
        return f"Ocurrió un error: {str(e)}"

# Definir el contexto del dataset
context = "prueba" # ---> este comando seria el que tiene que ir pero demora mucho en cargar por la longitud del DF: generate_context(data)

# Pregunta
question = "¿Cuáles son las ubicaciones de los incendios con una confianza mayor a 80?"

# Consulta
respuesta = ask_gpt(question, context)
print(respuesta)
# Out:
# Ocurrió un error: You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.
